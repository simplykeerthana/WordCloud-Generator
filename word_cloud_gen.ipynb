# %%
import matplotlib.pyplot as plt
import pandas as pd
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import download
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import json
from nltk.stem import WordNetLemmatizer

# %%
#loading the json files. 
data = pd.read_json('recipes.json', lines=True)

# %%
data.head(5)
# Out:
#                  Name                                                url  \
# 0  Christmas cupcakes  https://www.bbcgoodfood.com/recipes/72622/chri...
# 1      Christmas buns  https://www.bbcgoodfood.com/recipes/1803633/ch...
# 2  Christmas cupcakes  https://www.bbcgoodfood.com/recipes/981634/chr...
# 3      Christmas slaw  https://www.bbcgoodfood.com/recipes/890635/chr...
# 4      Christmas mess  https://www.bbcgoodfood.com/recipes/2806664/ch...
#
#                                          Description            Author  \
# 0  These beautiful and classy little cakes make l...     Sara Buenfeld
# 1  Paul Hollywood's fruit rolls can be made ahead...    Paul Hollywood
# 2  Made these for the second time today, and I ha...  Barney Desmazery
# 3  A nutty winter salad which is superhealthy, qu...         Good Food
# 4  Delicious and a synch to make! Have made this ...     Caroline Hire
#
#                                          Ingredients  \
# 0  [200g dark muscovado sugar, 175g butter, chopp...
# 1  [500g strong white flour, plus extra for dusti...
# 2  [280g self-raising flour, 175g golden caster s...
# 3  [2 carrots, halved, ½ white cabbage, shredded,...
# 4  l double cream, 400g Greek yoghurt, 4 tbs...
#
#                                               Method
# 0  [Tip the sugar, butter, dried fruit, whole che...
# 1  [Put the flour and 1 tsp salt into a large bow...
# 2  [Heat oven to 190C/170 fan/gas 5 and line a 12...
# 3  [Peel strips from the carrots using a vegetabl...
# 4  [In a small saucepan gently heat the frozen be...

# %%
data.head(5)
# Out:
#                  Name                                                url  \
# 0  Christmas cupcakes  https://www.bbcgoodfood.com/recipes/72622/chri...
# 1      Christmas buns  https://www.bbcgoodfood.com/recipes/1803633/ch...
# 2  Christmas cupcakes  https://www.bbcgoodfood.com/recipes/981634/chr...
# 3      Christmas slaw  https://www.bbcgoodfood.com/recipes/890635/chr...
# 4      Christmas mess  https://www.bbcgoodfood.com/recipes/2806664/ch...
#
#                                          Description            Author  \
# 0  These beautiful and classy little cakes make l...     Sara Buenfeld
# 1  Paul Hollywood's fruit rolls can be made ahead...    Paul Hollywood
# 2  Made these for the second time today, and I ha...  Barney Desmazery
# 3  A nutty winter salad which is superhealthy, qu...         Good Food
# 4  Delicious and a synch to make! Have made this ...     Caroline Hire
#
#                                          Ingredients  \
# 0  [200g dark muscovado sugar, 175g butter, chopp...
# 1  [500g strong white flour, plus extra for dusti...
# 2  [280g self-raising flour, 175g golden caster s...
# 3  [2 carrots, halved, ½ white cabbage, shredded,...
# 4  l double cream, 400g Greek yoghurt, 4 tbs...
#
#                                               Method
# 0  [Tip the sugar, butter, dried fruit, whole che...
# 1  [Put the flour and 1 tsp salt into a large bow...
# 2  [Heat oven to 190C/170 fan/gas 5 and line a 12...
# 3  [Peel strips from the carrots using a vegetabl...
# 4  [In a small saucepan gently heat the frozen be...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1615 entries, 0 to 1614
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         1615 non-null   object
#  1   url          1615 non-null   object
#  2   Description  1427 non-null   object
#  3   Author       1609 non-null   object
#  4   Ingredients  1615 non-null   object
#  5   Method       1615 non-null   object
# dtypes: object(6)
# memory usage: 75.8+ KB

# %%
data['Ingredients'].head(5)
# Out:
# 0    [200g dark muscovado sugar, 175g butter, chopp...
# 1    [500g strong white flour, plus extra for dusti...
# 2    [280g self-raising flour, 175g golden caster s...
# 3    [2 carrots, halved, ½ white cabbage, shredded,...
# 4    l double cream, 400g Greek yoghurt, 4 tbs...
# Name: Ingredients, dtype: object

# %%
#cleaning the dataset
data['Ingredients'] = data['Ingredients'].map(lambda x: re.sub(r'[^a-zA-Z ] ', ' ', str(x)))

# %%
data = data.dropna(subset=['Ingredients'])

# %%
#find stop words, along with recipe realted stopwords
stop = stopwords.words('english') + ['tsp', 'tbsp', 'finely','extra', 'chopped' ]
stop
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'tsp',
#  'tbsp',
#  'finely',
#  'extra',
#  'chopped']

# %%
def remove_encoding_word(word):
    word = str(word)
    word = word.encode('ASCII', 'ignore').decode('ASCII')
    return word

# %%
def remove_encoding_text(text):
    text = str(text)
    text = ' '.join(remove_encoding_word(word) for word in text.split() if word not in stop)
    return text

# %%
#lemmatize the text
data['Ingredients'] = data['Ingredients'].apply(remove_encoding_text)

# %%
text = ' '.join(words for words in data['Ingredients'])
len(text)
# Out:
# 408178

# %%
lemma = WordNetLemmatizer().lemmatize
lemma('leaves')
# Out:
# 'leaf'

# %%
#fit into the tf-idf model
def tokenize(document):
    tokens = [lemma(w) for w in document.split() if len(w) > 3 and w.isalpha()]
    return tokens

# %%
vectorizer = TfidfVectorizer(tokenizer = tokenize, ngram_range = ((2,2)), stop_words = stop, strip_accents = 'unicode')

# %%
tdm = vectorizer.fit_transform(data['Ingredients'])
# Out:
# /Users/keerthanamadhavan/opt/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['doe'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
vectorizer.vocabulary_.items()
# Out:
# dict_items([('dark muscovado', 3223), ('muscovado butter', 7093), ('butter luxury', 1208), ('luxury mixed', 6559), ('mixed dried', 6980), ('dried glac', 3681), ('glac grated', 4699), ('grated fresh', 4906), ('fresh root', 4369), ('root juice', 9536), ('juice dark', 5657), ('dark brandy', 3194), ('brandy orange', 855), ('orange pecannuts', 7653), ('pecannuts roughly', 8090), ('roughly large', 9637), ('large egg', 5868), ('egg ground', 3867), ('ground plain', 5144), ('plain baking', 8514), ('baking mixed', 342), ('mixed pack', 7018), ('pack used', 7829), ('used warm', 12321), ('warm apricotjam', 12605), ('apricotjam shredless', 190), ('shredless pack', 10231), ('pack fondant', 7759), ('fondant sugar', 4239), ('sugar gold', 11369), ('gold silver', 4733), ('silver gold', 10255), ('silver sugared', 10260), ('strong white', 11335), ('white flour', 12781), ('flour plus', 4199), ('plus sachet', 8773), ('sachet dried', 9745), ('dried unsalted', 3748), ('unsalted butter', 12149), ('butter softened', 1242), ('softened room', 10820), ('room unsalted', 9526), ('butter soft', 1241), ('soft brown', 10759), ('brown ground', 1031), ('ground dried', 5091), ('dried dried', 3668), ('dried caster', 3650), ('caster icing', 1573), ('golden caster', 4739), ('caster unsalted', 1632), ('butter natural', 1214), ('natural vanilla', 7225), ('vanilla unsalted', 12391), ('butter vanilla', 1257), ('vanilla icing', 12369), ('icing sugar', 5558), ('sugar green', 11372), ('green food', 5004), ('food christmas', 4242), ('christmas sweet', 2179), ('sweet sprinkle', 11538), ('sprinkle white', 10990), ('white chocolate', 12758), ('chocolate white', 2138), ('white chocolatebuttons', 12761), ('chocolatebuttons natural', 2143), ('natural colouring', 7209), ('colouring icing', 2640), ('icing pen', 5547), ('pen available', 8233), ('carrot white', 1480), ('white cabbage', 12749), ('cabbage pecan', 1308), ('pecan roughly', 8082), ('roughly spring', 9683), ('spring onion', 10979), ('onion pepper', 7542), ('pepper deseeded', 8240), ('deseeded maple', 3344), ('maple dijon', 6639), ('dijon olive', 3445), ('olive cider', 7361), ('double greek', 3543), ('greek lemon', 4986), ('lemon frozen', 6230), ('frozen mixed', 4460), ('mixed used', 7039), ('used black', 12213), ('black forest', 613), ('forest icing', 4274), ('icing pinch', 5548), ('unsalted buttercut', 12150), ('buttercut cube', 1268), ('cube plus', 3099), ('plus dark', 8676), ('dark chocolate', 3200), ('chocolate milk', 2111), ('milk chocolate', 6859), ('chocolate large', 2100), ('large golden', 5886), ('caster plain', 1605), ('plain cocoa', 8535), ('cocoa mixed', 2529), ('mixed sprig', 7033), ('sprig glac', 10948), ('glac caster', 4693), ('caster amaretti', 1508), ('amaretti biscuit', 66), ('biscuit chocolate', 577), ('chocolate used', 2136), ('used lindt', 12260), ('lindt gold', 6407), ('gold lustre', 4730), ('lustre icing', 6554), ('icing sugarfor', 5559), ('sugarfor chocolate', 11416), ('chocolate silver', 2127), ('cranberry lime', 2891), ('lime keep', 6387), ('keep zest', 5748), ('zest stem', 13233), ('pizza tomato', 8510), ('tomato pasta', 11924), ('pasta handful', 7999), ('handful leftover', 5319), ('leftover sausage', 6191), ('sausage stuffing', 9878), ('stuffing work', 11340), ('work well', 13138), ('well handful', 12701), ('leftover cooked', 6173), ('cooked turkey', 2720), ('turkey mozzarella', 12074), ('mozzarella pack', 7076), ('pack sage', 7807), ('sage leaf', 9756), ('leaf olive', 6048), ('butter rasher', 1230), ('rasher smoked', 9241), ('smoked streaky', 10707), ('streaky bacon', 11273), ('bacon plain', 291), ('plain worcestershire', 8611), ('worcestershire vegetable', 13132), ('vegetable well', 12503), ('pepper large', 8249), ('large aubergine', 5825), ('aubergine green', 218), ('green pepper', 5018), ('pepper weight', 8255), ('weight onion', 12687), ('onion peeled', 7541), ('peeled fairly', 8141), ('fairly hand', 3979), ('hand food', 5298), ('food clove', 4243), ('clove garlic', 2399), ('garlic granulated ...

# %%
#finally lets create the wordcloud. 
tfidf_weights = [(word, tdm.getcol(idx).sum()) for word, idx in vectorizer.vocabulary_.items()]

# %%
tfidf_weights[0:10]
# Out:
# [('dark muscovado', 7.19925237469466),
#  ('muscovado butter', 1.3095575592001647),
#  ('butter luxury', 0.5561055162200004),
#  ('luxury mixed', 1.110134004285181),
#  ('mixed dried', 6.146265055824797),
#  ('dried glac', 1.086516135213231),
#  ('glac grated', 0.5561055162200004),
#  ('grated fresh', 0.5561055162200004),
#  ('fresh root', 2.9441233250507133),
#  ('root juice', 0.5561055162200004)]

# %%
w = WordCloud(width=1500, height=1200, mode='RGBA', background_color='white', max_words=2000).fit_words(dict(tfidf_weigths))

# %%
plt.figure(figsize=(20,15))
plt.imshow(w)
plt.axis('off')
plt.savefig('recipes_wordcloud.png')
